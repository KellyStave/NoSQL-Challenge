# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with:  mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'fruits_db', 'local', 'met', 'traveldb', 'uk_food']

# %%
# assign the uk_food database to a variable name
uk_food_db = mongo['uk_food']

# %%
# review the collections in our new database
print(uk_food_db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
print(uk_food_db.establishments.find_one())
# Out:
# {'_id': ObjectId('63bee39dc091303a0db192bd'), 'FHRSID': 647177, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000041489', 'BusinessName': 'Wear Bay Bowls Club', 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843, 'AddressLine1': 'Wear Bay Road', 'AddressLine2': 'Folkestone', 'AddressLine3': 'Kent', 'AddressLine4': '', 'PostCode': 'CT19 6PY', 'Phone': '', 'RatingValue': '4', 'RatingKey': 'fhrs_4_en-gb', 'RatingDate': '2014-03-31T00:00:00', 'LocalAuthorityCode': '188', 'LocalAuthorityName': 'Folkestone and Hythe', 'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk', 'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 1.196408, 'latitude': 51.086058}, 'RightToReply': '', 'Distance': 4591.821311183521, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}

# %%
# assign the collection to a variable
establishments = uk_food_db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {"BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
query1 = {'AddressLine1': "Penang Flavours"}
results1 = establishments.find(query1)
for result in results1:
    print(result)
# Out:
# {'_id': ObjectId('63bee3a7b9d5362122706d47'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': '', 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.08384, 'latitude': 51.490142}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}
# {'_id': ObjectId('63beefa06089e560e852686e'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': '', 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query2 = {'BusinessType':"Restaurant/Cafe/Canteen"}
fields = {'BusinessTypeID':1, 'BusinessType':1}
results2 = establishments.find(query2, fields)
for result in results2:
    pprint(result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db192c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db192c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db192cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db192d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db192da')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db192e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db192e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db192e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db192ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db192ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db192f7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19301')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19309')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19310')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19313')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19317')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1931c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1931e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1931f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19322')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19323')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19324')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19326')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19327')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19328')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19333')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19334')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19337')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1933d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1933e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1933f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19343')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19344')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19347')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1934b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1934f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19350')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19352')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19353')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19355')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19357')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1935b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1935d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1935f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19361')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19362')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19363')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19365')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19372')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19374')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19375')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1937a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1937b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1937e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19382')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19384')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1938e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1938f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19390')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19395')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19396')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19398')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19399')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1939b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1939d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193a6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193aa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193ad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193b3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193b6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193d2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193db')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193eb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db193f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19410')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19413')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19415')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1941c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19420')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1943a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19440')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1944b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1944c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1944d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1944f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19457')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1945c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1945d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1945e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19460')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19462')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19463')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19465')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19466')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19467')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1946a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1946f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19474')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19477')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19478')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19479')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1947b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1947c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1947d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19480')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19489')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1948a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1948b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1948c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1948e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19490')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1949b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1949c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1949e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1949f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194a1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194c9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194dc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194e5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db194fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19500')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19505')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1950c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1950d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1950e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1950f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19514')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19519')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1951b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1951e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19520')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19525')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19528')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1952f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19530')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19532')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19533')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19534')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19535')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19538')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19539')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1953e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1953f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19541')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19543')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19546')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19547')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19548')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19549')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1954a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1954c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1954d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1954e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1954f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19550')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19554')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19555')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19557')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19559')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1955a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1955b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1955c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1955e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19567')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19568')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1956a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1956c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1956e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19571')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19577')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19579')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1957a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1957b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1957d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19582')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19589')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1958a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1958d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1959d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195b7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195b8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195cb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195cc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195eb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195ef')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db195f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19600')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19601')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1960a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19614')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19626')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1962d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1962e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19630')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19640')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19652')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1965e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19662')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19663')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19665')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19673')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19676')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19677')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1967b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19680')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196ad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196ba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196c4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196c9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196cb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196cc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196e5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db196f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19702')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19704')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1970c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19713')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19719')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1971e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19721')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19725')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19729')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1972a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19738')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1973a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1973f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19741')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19748')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1974d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19750')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19758')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19765')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1976b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1976d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19779')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1977b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1977e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19786')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19788')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19795')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19796')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1979b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1979c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1979f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197a8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197b9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197bb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197be')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197d3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197d7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197dd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197e4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197f0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197f5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197f8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db197ff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19800')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19801')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19804')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19809')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1980e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1980f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19817')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19821')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19827')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1982d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1982f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1983e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19840')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19842')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19847')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1984a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19852')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19856')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19857')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19859')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1985c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19860')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19862')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19868')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1986a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1986c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19870')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19871')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19872')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19876')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19877')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19878')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1987f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19880')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19882')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19886')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19895')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19899')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198bb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198bc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198bf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198d1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198e4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db198e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19903')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19905')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19906')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19907')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1990b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1990c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19912')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19931')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19932')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1993e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1993f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19940')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19943')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19944')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19946')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1994f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19950')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19953')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19955')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19958')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1995b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19961')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19965')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db1996b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39dc091303a0db19971')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22930')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22931')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22932')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22933')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22934')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22939')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db2293d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db2293f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22941')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22946')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db2294e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22952')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22954')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22955')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22958')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22959')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db2295a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db2295b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db2295c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db2295e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22960')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22964')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22965')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22966')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22967')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22968')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22969')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db2296d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22970')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22973')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22976')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22977')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22978')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22979')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db2297a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db2297c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22982')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22987')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db2298c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db2298e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22995')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db2299a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db2299b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db2299c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229a2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229b3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229db')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229ee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229f0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229f2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229f3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db229f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a05')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a0b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a0f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a13')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a16')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a1f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a26')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a27')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a2b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a32')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a35')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a36')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a39')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a3b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a48')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a53')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a54')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a61')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a66')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a6b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a6d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a73')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a74')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a7b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a7e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a80')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a82')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a83')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a91')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a92')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a93')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a94')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a98')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a9a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a9b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a9c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a9d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a9e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22a9f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22aa0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22aa4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22aa6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22aa9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22aaa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22aab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22aac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22aad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22aae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22aaf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22ab1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22ab2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22ab7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22aba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22abc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22ac3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22ac4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22ac5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22ac8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22ac9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22ad3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22ad6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22ae2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22ae8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22ae9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22aea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22aee')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22af2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22afb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22b05')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22b0d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22b10')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22b1b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22b1f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22b2b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22b2c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22b2d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22b31')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22b3d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('63bee39ec091303a0db22b42')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('63bee3a7b9d5362122706d47')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  '_id': ObjectId('63beefa06089e560e852686e')}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
uk_food_db.estblishments.update_many({'BusinessName': 'Penang Flavours'}, {'$set' : {'BusinessTypeID': 1}})

# %%
# Confirm that the new restaurant was updated
print(uk_food_db.establishments.find_one({'BusinessName':'Penang Flavours'}))
# Out:
# {'_id': ObjectId('63bee3a7b9d5362122706d47'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': '', 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.08384, 'latitude': 51.490142}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query3 = {'LocalAuthorityName': 'Dover'}
result3 = establishments.count_documents(query3)
print(result3)
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many(query3)

# %%
# Check if any remaining documents include Dover
result4 = establishments.find(query3)
for result in result4:
    print(result)

# %%
# Check that other documents remain with 'find_one'
result5 = establishments.find_one()
print(result5)
# Out:
# {'_id': ObjectId('63bee39dc091303a0db192bd'), 'FHRSID': 647177, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000041489', 'BusinessName': 'Wear Bay Bowls Club', 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843, 'AddressLine1': 'Wear Bay Road', 'AddressLine2': 'Folkestone', 'AddressLine3': 'Kent', 'AddressLine4': '', 'PostCode': 'CT19 6PY', 'Phone': '', 'RatingValue': '4', 'RatingKey': 'fhrs_4_en-gb', 'RatingDate': '2014-03-31T00:00:00', 'LocalAuthorityCode': '188', 'LocalAuthorityName': 'Folkestone and Hythe', 'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk', 'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '1.196408', 'latitude': '51.086058'}, 'RightToReply': '', 'Distance': 4591.821311183521, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers. Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude
establishments.update_many({}, [{'$set': {'geocode.longitude': {'$toDouble': '$geocode.longitude'}}}])

# %%
# Change the data type from String to Decimal for latitude
establishments.update_many({}, [{'$set': {'geocode.latitude': {'$toDouble': '$geocode.latitude'}}}])

# %%
# Check that the coordinates are now numbers
result6 = establishments.find_one()
print(result6)
# Out:
# {'_id': ObjectId('63bee39dc091303a0db192bd'), 'FHRSID': 647177, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000041489', 'BusinessName': 'Wear Bay Bowls Club', 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843, 'AddressLine1': 'Wear Bay Road', 'AddressLine2': 'Folkestone', 'AddressLine3': 'Kent', 'AddressLine4': '', 'PostCode': 'CT19 6PY', 'Phone': '', 'RatingValue': '4', 'RatingKey': 'fhrs_4_en-gb', 'RatingDate': '2014-03-31T00:00:00', 'LocalAuthorityCode': '188', 'LocalAuthorityName': 'Folkestone and Hythe', 'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk', 'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 1.196408, 'latitude': 51.086058}, 'RightToReply': '', 'Distance': 4591.821311183521, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}
